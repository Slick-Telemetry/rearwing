# %%
import fastf1
import pandas as pd
from fastf1.ergast import Ergast

# Pandas options
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# Ergast options
ergast = Ergast(result_type="pandas", auto_cast=True)

# %%
event_schedule_2023 = fastf1.get_event_schedule(2023)
event_schedule_2023
# Out:
# req         WARNING
#
# DEFAULT CACHE ENABLED!
# 	Cache directory: /Users/pratik/Library/Caches/fastf1.
# 	Size: 104.31 MB
#     RoundNumber        Country           Location  \
# 0             0        Bahrain             Sakhir
# 1             1        Bahrain             Sakhir
# 2             2   Saudi Arabia             Jeddah
# 3             3      Australia          Melbourne
# 4             4     Azerbaijan               Baku
# 5             5  United States              Miami
# 6             6         Monaco             Monaco
# 7             7          Spain          Barcelona
# 8             8         Canada           Montréal
# 9             9        Austria          Spielberg
# 10           10  Great Britain        Silverstone
# 11           11        Hungary           Budapest
# 12           12        Belgium  Spa-Francorchamps
# 13           13    Netherlands          Zandvoort
# 14           14          Italy              Monza
# ...

# %%
event_bahraingp = event_schedule_2023.get_event_by_name("Bahrain Grand Prix")

quali_event = event_bahraingp.get_qualifying()
quali_event.load(
    laps=True,
    telemetry=False,
    weather=False,
    messages=False,
)
quali_event.results
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '16', '55', '14', '63', '44', '18', '31', '27', '4', '77', '24', '22', '23', '2', '20', '81', '21', '10']
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 11           11       S PEREZ          PER            perez  Red Bull Racing
# 16           16     C LECLERC          LEC          leclerc          Ferrari
# ...

# %%
race_event = event_bahraingp.get_race()
race_event.load(
    laps=True,
    telemetry=True,
    weather=True,
    messages=True,
)
race_event.results
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '14', '55', '44', '18', '63', '77', '10', '23', '22', '2', '20', '21', '27', '24', '4', '31', '16', '81']
# ...

# %%
race_event.laps
# Out:
#                        Time Driver DriverNumber                LapTime  \
# 0    0 days 01:04:15.961000    VER            1 0 days 00:01:39.019000
# 1    0 days 01:05:53.935000    VER            1 0 days 00:01:37.974000
# 2    0 days 01:07:31.941000    VER            1 0 days 00:01:38.006000
# 3    0 days 01:09:09.917000    VER            1 0 days 00:01:37.976000
# 4    0 days 01:10:47.952000    VER            1 0 days 00:01:38.035000
# ...                     ...    ...          ...                    ...
# 1051 0 days 01:17:53.364000    PIA           81 0 days 00:01:41.534000
# 1052 0 days 01:19:34.948000    PIA           81 0 days 00:01:41.584000
# 1053 0 days 01:21:16.300000    PIA           81 0 days 00:01:41.352000
# 1054 0 days 01:22:57.456000    PIA           81 0 days 00:01:41.156000
# 1055 0 days 01:24:59.527000    PIA           81 0 days 00:02:02.071000
#
#       LapNumber  Stint PitOutTime              PitInTime  \
# ...

# %%
driver_standings_2023_miami = ergast.get_driver_standings(season=2023, round=5)
driver_standings_2023_miami.content[0]
# Out:
#     position positionText  points  wins         driverId  driverNumber  \
# 0          1            1   119.0     3   max_verstappen            33
# 1          2            2   105.0     2            perez            11
# 2          3            3    75.0     0           alonso            14
# 3          4            4    56.0     0         hamilton            44
# 4          5            5    44.0     0            sainz            55
# 5          6            6    40.0     0          russell            63
# 6          7            7    34.0     0          leclerc            16
# 7          8            8    27.0     0           stroll            18
# 8          9            9    10.0     0           norris             4
# 9         10           10     8.0     0            gasly            10
# 10        11           11     6.0     0       hulkenberg            27
# 11        12           12     6.0     0             ocon            31
# ...

# %%
driver_standings_2023 = ergast.get_driver_standings(season=2023)
driver_standings_2023.content[0]
# Out:
#     position positionText  points  wins         driverId  driverNumber  \
# 0          1            1   575.0    19   max_verstappen            33
# 1          2            2   285.0     2            perez            11
# 2          3            3   234.0     0         hamilton            44
# 3          4            4   206.0     0           alonso            14
# 4          5            5   206.0     0          leclerc            16
# 5          6            6   205.0     0           norris             4
# 6          7            7   200.0     1            sainz            55
# 7          8            8   175.0     0          russell            63
# 8          9            9    97.0     0          piastri            81
# 9         10           10    74.0     0           stroll            18
# 10        11           11    62.0     0            gasly            10
# 11        12           12    58.0     0             ocon            31
# ...

# %%
constructor_standings_2023 = ergast.get_constructor_standings(season=2023)
constructor_standings_2023.content[0]
# Out:
#    position positionText  points  wins constructorId  \
# 0         1            1   860.0    21      red_bull
# 1         2            2   409.0     0      mercedes
# 2         3            3   406.0     1       ferrari
# 3         4            4   302.0     0       mclaren
# 4         5            5   280.0     0  aston_martin
# 5         6            6   120.0     0        alpine
# 6         7            7    28.0     0      williams
# 7         8            8    25.0     0    alphatauri
# 8         9            9    16.0     0          alfa
# 9        10           10    12.0     0          haas
#
#                                                  constructorUrl  \
# 0                  http://en.wikipedia.org/wiki/Red_Bull_Racing
# 1     http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One
# 2                 http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 3                          http://en.wikipedia.org/wiki/McLaren
# ...

# %%
race_event.session_info
# Out:
# {'Meeting': {'Key': 1141,
#   'Name': 'Bahrain Grand Prix',
#   'OfficialName': 'FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2023',
#   'Location': 'Sakhir',
#   'Country': {'Key': 36, 'Code': 'BRN', 'Name': 'Bahrain'},
#   'Circuit': {'Key': 63, 'ShortName': 'Sakhir'}},
#  'ArchiveStatus': {'Status': 'Generating'},
#  'Key': 7953,
#  'Type': 'Race',
#  'Name': 'Race',
#  'StartDate': datetime.datetime(2023, 3, 5, 18, 0),
#  'EndDate': datetime.datetime(2023, 3, 5, 20, 0),
#  'GmtOffset': datetime.timedelta(seconds=10800),
#  'Path': '2023/2023-03-05_Bahrain_Grand_Prix/2023-03-05_Race/'}

# %%
race_event.track_status
# Out:
#                      Time Status      Message
# 0  0 days 00:05:28.637000      1     AllClear
# 1  0 days 00:21:59.040000      2       Yellow
# 2  0 days 00:22:03.165000      1     AllClear
# 3  0 days 01:03:07.651000      2       Yellow
# 4  0 days 01:03:08.151000      1     AllClear
# 5  0 days 01:04:15.978000      2       Yellow
# 6  0 days 01:04:51.243000      1     AllClear
# 7  0 days 02:08:59.830000      2       Yellow
# 8  0 days 02:09:18.298000      6  VSCDeployed
# 9  0 days 02:10:53.875000      7    VSCEnding
# 10 0 days 02:11:06.437000      1     AllClear

# %%
race_event.race_control_messages
# Out:
#                   Time Category  \
# 0  2023-03-05 14:04:34    Other
# 1  2023-03-05 14:20:00     Flag
# 2  2023-03-05 14:23:00     Flag
# 3  2023-03-05 14:23:04     Flag
# 4  2023-03-05 14:30:00    Other
# ..                 ...      ...
# 68 2023-03-05 16:37:31     Flag
# 69 2023-03-05 16:40:53    Other
# 70 2023-03-05 16:42:16    Other
# 71 2023-03-05 16:42:37    Other
# 72 2023-03-05 16:42:52    Other
#
#                                                                                       Message  \
# 0                                                     PINK HEAD PADDING MATERIAL MUST BE USED
# 1                                                                 GREEN LIGHT - PIT EXIT OPEN
# 2                                                                   YELLOW IN TRACK SECTOR 10
# 3                                                                    CLEAR IN TRACK SECTOR 10
# 4                                                                             PIT EXIT CLOSED
# ...

# %%
race_event.weather_data
# Out:
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0   0 days 00:00:45.438000     29.8      19.0    1016.5     False       35.1
# 1   0 days 00:01:45.453000     29.7      19.0    1016.5     False       35.0
# 2   0 days 00:02:45.452000     29.7      19.0    1016.5     False       34.9
# 3   0 days 00:03:45.466000     29.6      19.0    1016.5     False       34.9
# 4   0 days 00:04:45.449000     29.6      19.0    1016.5     False       34.8
# ..                     ...      ...       ...       ...       ...        ...
# 156 0 days 02:36:46.050000     26.3      21.0    1017.4     False       28.7
# 157 0 days 02:37:46.064000     26.3      21.0    1017.4     False       28.7
# 158 0 days 02:38:46.063000     26.3      21.0    1017.5     False       28.7
# 159 0 days 02:39:46.109000     26.3      21.0    1017.4     False       28.7
# 160 0 days 02:40:46.061000     26.2      21.0    1017.5     False       28.7
#
#      WindDirection  WindSpeed
# ...

# %%
event_schedule_2023.iloc[1].Session5Date
# Out:
# Timestamp('2023-03-05 18:00:00+0300', tz='UTC+03:00')

# %%
race_event.session_start_time
# Out:
# datetime.timedelta(seconds=3756, microseconds=652000)
